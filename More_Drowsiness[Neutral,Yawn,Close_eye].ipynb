# %%
# !nvidia-smi
# Out:
# Tue Mar 26 11:10:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.13                 Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P8               6W /  95W |      0MiB /  4096MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.3 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Setup complete  (16 CPUs, 15.3 GB RAM, 307.6/361.3 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qERaAo1Ts8gHG3aN1lqa")
project = rf.workspace("2226346413-qq-com").project("moredrowsiness")
version = project.version(4)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov5s.pt data=/content/MoreDrowsiness-4/data.yaml epochs=200 imgsz=640 plots=True
# Out:
# /content
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# New https://pypi.org/project/ultralytics/8.1.33 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt conf=0.25 source='/content/Twitch streamer starts to fall asleep while driving....avi' save=True
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5s summary (fused): 193 layers, 9112697 parameters, 0 gradients, 23.8 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/1801) /content/Twitch streamer starts to fall asleep while driving....avi: 384x640 1 Neutral, 187.9ms
# video 1/1 (2/1801) /content/Twitch streamer starts to fall asleep while driving....avi: 384x640 1 Neutral, 13.8ms
# video 1/1 (3/1801) /content/Twitch streamer starts to fall asleep while driving....avi: 384x640 1 Neutral, 13.1ms
# video 1/1 (4/1801) /content/Twitch streamer starts to fall asleep while driving....avi: 384x640 1 Neutral, 13.2ms
# video 1/1 (5/1801) /content/Twitch streamer starts to fall asleep while driving....avi: 384x640 1 Neutral, 13.0ms
# video 1/1 (6/1801) /content/Twitch streamer starts to fall asleep while driving....avi: 384x640 1 Neutral, 13.5ms
# ...
